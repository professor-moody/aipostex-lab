# %% [markdown]
# # RAG Pipeline Prototype
# Testing document retrieval against the ML team's ChromaDB instance.
# **Author:** dev@acme.corp
# **Last Updated:** 2025-11-20

# %%
# Quick and dirty — don't commit this to git
import os
os.environ['OPENAI_API_KEY'] = 'sk-proj-FAKE-notebook-key-1234567890abcdef'
os.environ['ANTHROPIC_API_KEY'] = 'sk-ant-FAKE-notebook-key-abcdef1234567890'

# ChromaDB on the ML platform server
CHROMA_HOST = '172.16.50.20'
CHROMA_PORT = 8000
COLLECTION = 'acme-knowledge-base'

# Prod DB for structured queries
DB_URI = 'postgresql://chatbot:Ch4tb0tPwd!@db-dev-01.acme.internal:5432/chatbot_dev'

# %%
import chromadb

client = chromadb.HttpClient(host=CHROMA_HOST, port=CHROMA_PORT)
collection = client.get_collection(COLLECTION)

print(f'Connected to ChromaDB. Collection "{COLLECTION}" has {collection.count()} documents.')

# %%
# Test semantic search
results = collection.query(
    query_texts=['employee salary information'],
    n_results=3
)

for doc in results['documents'][0]:
    print(doc[:200])
    print('---')

# %%
# TODO: Hook up to LangChain for full RAG pipeline
# from langchain.vectorstores import Chroma
# from langchain.chat_models import ChatOpenAI
# llm = ChatOpenAI(model='gpt-4', api_key=os.environ['OPENAI_API_KEY'])
